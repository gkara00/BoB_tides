# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
from netCDF4 import Dataset
from scipy.io import netcdf #### <--- This is the library to import.
import xarray as xr
import xrft
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import cmocean.cm as cmo
import cmaps
import numpy as np
from scipy import signal
import cmocean

import datetime 
import os

# %matplotlib inline
plt.rcParams["font.size"] = 14

# %%
# some colors
c1 = 'slateblue'
c2 = 'tomato'
c3 = 'k'
c4 = 'indigo'

# %%
root_dir = '/home/gkara/Documents/for-tide_paper/'
#
gridT = !ls /home/gkara/Documents/for-tide_paper/ref/*1h_gridT*
#
_gridT = !ls /home/gkara/Documents/for-tide_paper/exp1/*1h_gridT*
#
dsT = xr.open_mfdataset(gridT, combine='by_coords')
dsT_ = xr.open_mfdataset(_gridT, combine='by_coords')

# %%
import glob
#
root_dir = '/home/gkara/Documents/for-tide_paper/'
def _fnames(arch, season):
        
    if season == 'winter':
        fnames = glob.glob(arch + 'BISCAY-T60_1h_gridT_20120[1-3]??-20120[1-3]??.nc') #winter
    elif season == 'summer':
        fnames = glob.glob(arch + 'BISCAY-T60_1h_gridT_20110[7-9]??-20110[7-9]??.nc') #summer
    return fnames

dsT_s = xr.open_mfdataset(_fnames(root_dir + 'ref/','summer'), combine='by_coords')
dsT_s_ = xr.open_mfdataset(_fnames(root_dir + 'exp1/', 'summer'), combine='by_coords')
#
dsT_w = xr.open_mfdataset(_fnames(root_dir + 'ref/','winter'), combine='by_coords')
dsT_w_ = xr.open_mfdataset(_fnames(root_dir + 'exp1/', 'winter'), combine='by_coords')

# %% [markdown]
# #### load daily grid_2D (ssh = sossheig-ssh_ib)

# %%
import glob
root_dir = '/home/gkara/Documents/for-tide_paper/'
ds2D = xr.open_mfdataset(glob.glob(root_dir + 'ref/' + 'BISCAY-T60_1d_grid2D_ssh-ib_20110706-20120629.nc'), combine='by_coords')
ds2D_ = xr.open_mfdataset(glob.glob(root_dir + 'exp1/' + 'BISCAY-T60_1d_grid2D_ssh-ib_20110706-20120629.nc'), combine='by_coords')

# %%
#Englishc Channel
ds2D.isel(x=286,y=470).SSH.plot()
ds2D_.isel(x=286,y=470).SSH.plot()

# %%
dsT

# %%
dsUV = xr.merge([xr.open_mfdataset(gridU, combine='by_coords'), \
              xr.open_mfdataset(gridV, combine='by_coords')], compat='override')
dsUV_ = xr.merge([xr.open_mfdataset(_gridU, combine='by_coords'), \
              xr.open_mfdataset(_gridV, combine='by_coords')], compat='override')

# %%
def _sel_region(ds1, ds2, season):
    dssh_ab = ds1.isel(x=88,y=230)
    dssh_ab_ = ds2.isel(x=88,y=230)
    dssh_ar = ds1.isel(x=312,y=278)
    dssh_ar_ = ds2.isel(x=312,y=278)
    dssh_ec = ds1.isel(x=286,y=470)
    dssh_ec_ = ds2.isel(x=286,y=470)
    # save
    np.savez('../data/SSH_freq_spectra_' + season + '.npz', \
         abbysal = dssh_ab.sossheig.values, \
         abbysal_ = dssh_ab_.sossheig.values, \
         armorican = dssh_ar.sossheig.values, \
         armorican_ = dssh_ar_.sossheig.values, \
         channel = dssh_ec.sossheig.values, \
         channel_ = dssh_ec_.sossheig.values)
    return
_sel_region(dsT_s, dsT_s_, 'summer')
_sel_region(dsT_w, dsT_w_, 'winter')

# %%
#compute coriolis frequency 
def _coriolis_f(lat):
        # Omega is the Earth's rotation rate, expressed in radians per second
    omega = 7.2921e-5 * 13750.99 # cycles per day / 7.2921e-5 rad/s

    # `f = 2 * omega * sin(phi)`, which is computed for each grid point over
    # the globe from the 2-dimensional latitude array.
    f = 2. * omega * np.sin(np.radians(lat))
    return f

print('Latitude - abyssal plain:', bathy.isel(x=88,y=230).nav_lat.values)
print('Latitude - Armorican shelf:', bathy.isel(x=312,y=278).nav_lat.values)
print('Latitude - English Channel:', bathy.isel(x=286,y=470).nav_lat.values)

f_abyssal = _coriolis_f(46.31301)
f_abyssal
# Out:
# Latitude - abyssal plain: 45.636467
# Latitude - Armorican shelf: 46.31301
# Latitude - English Channel: 49.910713
# 1.4502048585616016

# %%
dssh_ab = dsT.isel(x=88,y=230,time_counter=slice(0,2040))
dssh_ab_ = dsT_.isel(x=88,y=230,time_counter=slice(0,2040))
dssh_ar = dsT.isel(x=312,y=278,time_counter=slice(0,2040))
dssh_ar_ = dsT_.isel(x=312,y=278,time_counter=slice(0,2040))
dssh_ec = dsT.isel(x=286,y=470,time_counter=slice(0,2040))
dssh_ec_ = dsT_.isel(x=286,y=470,time_counter=slice(0,2040))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-be9d5613cd12> in <module>
# ----> 1 dssh_ab = dsT.isel(x=88,y=230,time_counter=slice(0,2040))
#       2 dssh_ab_ = dsT_.isel(x=88,y=230,time_counter=slice(0,2040))
#       3 dssh_ar = dsT.isel(x=312,y=278,time_counter=slice(0,2040))
#       4 dssh_ar_ = dsT_.isel(x=312,y=278,time_counter=slice(0,2040))
#       5 dssh_ec = dsT.isel(x=286,y=470,time_counter=slice(0,2040))
#
# NameError: name 'dsT' is not defined

# %%
a = np.sqrt(dsUV.isel(x=88,y=230).sozocrtx.values)

# %%
np.savez('SSH_freq_spectra.npz', \
         abbysal = dssh_ab.sossheig.values, \
         abbysal_ = dssh_ab_.sossheig.values, \
         armorican = dssh_ar.sossheig.values, \
         armorican_ = dssh_ar_.sossheig.values, \
         channel = dssh_ec.sossheig.values, \
         channel_ = dssh_ec_.sossheig.values)

# %%
np.savez('../data/SSH_time_counter.npz',time = dsT_s.time_counter.values)

# %%
data = np.load('../data/SSH_freq_spectra_.npz')
time = np.load('../data/SSH_time_counter.npz')
time.files
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-56ed308bdd86> in <module>
# ----> 1 data = np.load('../data/SSH_freq_spectra_.npz')
#       2 time = np.load('../data/SSH_time_counter.npz')
#       3 time.files
#
# ~/anaconda3/envs/dell/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/SSH_freq_spectra_.npz'

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, figsize = (12,8))
plt.subplots_adjust(hspace=0.4)
axes[0].plot(time['time'][1365:6481], data['channel'][1365:6481], color=c3, label='English Channel', alpha=0.8)
axes[0].plot(time['time'][1365:6481], data['armorican'][1365:6481], color=c2, label='Armorican shelf', alpha=0.8)
axes[0].plot(time['time'][1365:6481], data['abbysal'][1365:6481], color=c1, label='abyssal plain', alpha=0.8)
axes[0].legend(ncol=3, loc='center', bbox_to_anchor=(0.5, -0.2))

axes[0].set_xticklabels('')

axes[1].plot(time['time'][1365:6481], data['channel_'][1365:6481], color=c3, label='English Channel', alpha=0.8)
axes[1].plot(time['time'][1365:6481], data['armorican_'][1365:6481], color=c2, label='Armorican shelf', alpha=0.8)
axes[1].plot(time['time'][1365:6481], data['abbysal_'][1365:6481], color=c1, label='abyssal plain', alpha=0.8)

ds2D.isel(x=286,y=470).SSH.plot(ax=axes[2], color='mediumseagreen', label='English Channel TON detided')
ds2D_.isel(x=286,y=470).SSH.plot(ax=axes[2], color='gray', label='English Channel TOFF')
axes[2].set_xlabel('')
axes[2].set_xlim(ds2D.sel(time_counter='2011-09-01').time_counter.values, ds2D.sel(time_counter='2012-02-29').time_counter.values)
plt.xticks(rotation=0)
axes[2].set_ylim(-0.4, 0.05)
axes[2].legend(ncol=2, loc='upper center', bbox_to_anchor=(0.5, 1.35))

idx = ['(a)', '(b)', '(c)']
for i, ax in enumerate(axes.flat):
    ax.set_ylabel('SSH (m)')
    ax.grid()
    if i<2:  
        ax.set_xlim(time['time'][1365], time['time'][5735])    #time['time'][1365], time['time'][5737])
        ax.set_xticklabels('')    
    ax.annotate(idx[i], xy=(0, 1), xycoords='axes fraction', fontsize=14,
        xytext=(20, 5), textcoords='offset points',
        ha='right', va='bottom')

#save figure
fig.savefig('/home/gkara/Documents/paper-tides/' + '_plots/fig_SSH_.png',dpi=300,bbox_inches='tight')

# %%
# tidal constituents
# from scipy.io import loadmat
# annots = loadmat('/home/gkara/Downloads/tidal_freq.mat')
constituents = [('M2', 12.4206012), ('S2', 12.), ('N2', 12.65834751), ('K2', 11.96723606),\
                ('K1', 23.93447213), ('O1', 25.81933871), ('Q1', 26.86835), ('P1', 24.06588766),\
                ('Mf', 327.8599387), ('Mm', 661.3111655),\
                ('M4', 6.2103006)]
##############################
data = np.load('SSH_freq_spectra_summer.npz')
fs=24
###
f1, Ps1_TON = signal.welch(data['abbysal'], fs, nperseg=720)
f1, Ps1_TOFF = signal.welch(data['abbysal_'], fs, nperseg=720)
#
f2, Ps2_TON = signal.welch(data['armorican'], fs, nperseg=720)
f2, Ps2_TOFF = signal.welch(data['armorican_'], fs, nperseg=720)
#
f3, Ps3_TON = signal.welch(data['channel'], fs, nperseg=720)
f3, Ps3_TOFF = signal.welch(data['channel_'], fs, nperseg=720)
##############################

fig = plt.figure(figsize = (10,20))
ax0=plt.subplot(311)
#
ax0.loglog(f3,Ps3_TON,'-',color=c3,label='English Channel')
ax0.loglog(f3,Ps3_TOFF,'--',color=c3)
#
ax0.loglog(f2,Ps2_TON,'-',color=c2,label='Armorican shelf')
ax0.loglog(f2,Ps2_TOFF,'--',color=c2)
#
ax0.loglog(f1,Ps1_TON,'-',color=c1,label='abyssal plain')
ax0.loglog(f1,Ps1_TOFF,'--',color=c1)
#
# ax0.plot(np.array(t_f),1.0e-9*np.ones(11),'r|')
ax0.grid()
kappa = [1.1e-9, 1.0e-8, 3.0e-8, 3.0e-9, 1.1e-9, 1.0e-8, 3.0e-8, 3.0e-9]
for k,f in enumerate(constituents):
    if k<8:
        ax0.text(24./f[1], kappa[k], f[0], size=10)
    else:
        ax0.text(24./f[1], 1.1e-9, f[0], size=10)
#
ax0.set_xlim(0.0333,12)
ax0.set_ylabel('SSH power spectrum (m$^{2}$cpd$^{-1}$)')
ax0.set_xlabel(r'Frequency (cpd)')
plt.legend(loc=2)
#save figure
# fig.savefig('/home/gkara/Documents/paper-tides/_plots/fig_ssh_spectra.png',dpi=300,bbox_inches='tight')

# %%
def _spectra_plot(ax, _data):
    # tidal constituents
    # from scipy.io import loadmat
    # annots = loadmat('/home/gkara/Downloads/tidal_freq.mat')
    constituents = [('K2', 11.96723606), ('M2', 12.4206012), ('N2', 12.65834751), ('S2', 12.),\
                    ('K1', 23.93447213), ('O1', 25.81933871), ('Q1', 26.86835), ('P1', 24.06588766),\
                    ('Mf', 327.8599387), ('Mm', 661.3111655),\
                    ('M4', 6.2103006)]
    ##############################
    data = np.load(_data)
    fs=24
    ###
    f1, Ps1_TON = signal.welch(data['abbysal'], fs, nperseg=720)
    f1, Ps1_TOFF = signal.welch(data['abbysal_'], fs, nperseg=720)
    #
    f2, Ps2_TON = signal.welch(data['armorican'], fs, nperseg=720)
    f2, Ps2_TOFF = signal.welch(data['armorican_'], fs, nperseg=720)
    #
    f3, Ps3_TON = signal.welch(data['channel'], fs, nperseg=720)
    f3, Ps3_TOFF = signal.welch(data['channel_'], fs, nperseg=720)
    ##############################

#     fig = plt.figure(figsize = (10,20))
#     ax0=plt.subplot(311)
    #
    ax.loglog(f3,Ps3_TON,'-',color=c3,label='English Channel')
    ax.loglog(f3,Ps3_TOFF,'--',color=c3)
    #
    ax.loglog(f2,Ps2_TON,'-',color=c2,label='Armorican shelf')
    ax.loglog(f2,Ps2_TOFF,'--',color=c2)
    #
    ax.loglog(f1,Ps1_TON,'-',color=c1,label='abyssal plain')
    ax.loglog(f1,Ps1_TOFF,'--',color=c1)
    #
    # ax.plot(np.array(t_f),1.0e-9*np.ones(11),'r|')
    ax.grid()
    kappa = [1.1e-9, 1.01e-8, 3.0e-8, 3.0e-9, 1.1e-9, 1.01e-8, 3.0e-8, 3.0e-9]
    for k,f in enumerate(constituents):
        if k<8:
            ax.text(24./f[1], kappa[k], f[0], size=10)
        else:
            ax.text(24./f[1], 1.1e-9, f[0], size=10)
    #
    ax.set_xlim(0.0333,10)
    ax.set_ylabel('SSH power spectrum (m$^{2}$cpd$^{-1}$)')
    ax.set_xlabel(r'Frequency (cpd)')
    plt.legend(ncol=2, loc=2)

# %%
fig = plt.figure(figsize = (20,5))
ax0=plt.subplot(121)
_spectra_plot(ax0,'SSH_freq_spectra_summer.npz')
ax1=plt.subplot(122)
_spectra_plot(ax1,'SSH_freq_spectra_winter.npz')
####
idx = ['$(a)$ ' + 'Summer', '$(b)$ ' + 'Winter']
ax0.annotate(idx[0], xy=(.13, 1), xycoords='axes fraction', fontsize=14,
    xytext=(20, 5), textcoords='offset points',
    ha='right', va='bottom')
ax1.annotate(idx[1], xy=(.11, 1), xycoords='axes fraction', fontsize=14,
    xytext=(20, 5), textcoords='offset points',
    ha='right', va='bottom')
#save figure
fig.savefig('/home/gkara/Documents/paper-tides/_plots/fig_ssh_spectra_.png',dpi=300,bbox_inches='tight')

# %% [markdown]
# ## KE

# %%
KE_ab = np.sqrt(dKE_ab.sozocrtx.values**2.0 + dKE_ab.somecrty.values**2.0)
KE_ab_ = np.sqrt(dKE_ab_.sozocrtx.values**2.0 + dKE_ab_.somecrty.values**2.0)
#
KE_ar = np.sqrt(dKE_ar.sozocrtx.values**2.0 + dKE_ar.somecrty.values**2.0)
KE_ar_ = np.sqrt(dKE_ar_.sozocrtx.values**2.0 + dKE_ar_.somecrty.values**2.0)
#
KE_ec = np.sqrt(dKE_ec.sozocrtx.values**2.0 + dKE_ec.somecrty.values**2.0)
KE_ec_ = np.sqrt(dKE_ec_.sozocrtx.values**2.0 + dKE_ec_.somecrty.values**2.0)

# %%
np.savez('KE_freq_spectra.npz', \
         abbysal = KE_ab, \
         abbysal_ = KE_ab_, \
         armorican = KE_ar, \
         armorican_ = KE_ar_, \
         channel = KE_ec, \
         channel_ = KE_ec_)

# %%
data = np.load('KE_freq_spectra.npz')
data.files

# %%
fs=24
f1, Ps1_TON = signal.welch(data['abbysal'], fs, nperseg=720)
f1, Ps1_TOFF = signal.welch(data['abbysal_'], fs, nperseg=720)
#
f2, Ps2_TON = signal.welch(data['armorican'], fs, nperseg=720)
f2, Ps2_TOFF = signal.welch(data['armorican_'], fs, nperseg=720)
#
f3, Ps3_TON = signal.welch(data['channel'], fs, nperseg=720)
f3, Ps3_TOFF = signal.welch(data['channel_'], fs, nperseg=720)

# %%
tidal_f = [('Mm', 12.4206012), ('Mf', 12), ('Q1', 12.65834751), ('O1', 23.93447213), ('P1', 25.81933871), ('K1', 26.868350), \
           ('N2', 6.210300601), ('M2', 11.96723606), ('S2', 24.06588766), ('K2', 327.8599387), ('M4', 661.3111655)]
t_f = [24/f[1] for f in tidal_f]
fig = plt.figure(figsize = (10,20))
ax0=plt.subplot(311)
# ax0.loglog(f1,Ps1_TON,'-',color=c1,label='Abyssal Plain')
# ax0.loglog(f1,Ps1_TOFF,'--',color=c1)

ax0.loglog(f2,Ps2_TON,'-',color=c2,label='Armorican shelf')
ax0.loglog(f2,Ps2_TOFF,'--',color=c2)
# #
# ax0.loglog(f3,Ps3_TON,'-',color=c3,label='English channel')
# ax0.loglog(f3,Ps3_TOFF,'--',color=c3)
#
ax0.plot(np.array(t_f),1.0e-9*np.ones(11),'r|')
#
ax0.set_xlim(0.0333,12)
ax0.set_ylabel('KE power spectrum (m$^{2}$cpd$^{-1}$)')
ax0.set_xlabel(r'Frequency (cpd)')
ax0.grid()
plt.legend()

# %%
def spec_est_time(U,dt):
    """ Computes spectral estimate in time (axis=2) """
    kx = U.shape
    N = int(kx[0])          # record length)
    df = 1./(N*dt)  # frequency resolution [cycles / (unit time)]
    fNy = 1./(2*dt) # Nyquist frequency
    an = np.fft.fft(U,axis=0)

    an = an[1:4319]
    E = 2*(an*an.conj())/df/(N**2)  # spectral estimate
    f = np.arange(1,N/2-1)*df
    return E,f,df,fNy

# %%
psd, f, df , fn = spec_est_time(dssh_ab.sossheig.values, 1)

# %%
plt.plot(f,psd)

# %%
dsT.sossheig

# %%
def pow_spec_2d(x, axis=[-1,-2]):
    # x and time
    f = np.fft.fftn(x, axes=axis)
    return np.real(f * f.conj())

# operate on a dataarray
def xray_isotropic_power_spectrum(da, kiso=None, axis=('y','x')):
    axis_num = [da.get_axis_num(a) for a in axis]
    # see if there are other coords to leave alone
    other_axis = set(da.dims).difference(axis)
    if other_axis:
        other_axis_num = [da.get_axis_num for a in other_axis]
    
    # calcualte wavenumbers from axes
    N = [da.shape[n] for n in axis_num]
    delta_x = [np.diff(da[a])[0] for a in axis]
    k = [ np.fft.fftfreq(Nx, dx) for (Nx, dx) in zip(N, delta_x)]
    kk = np.array(np.meshgrid(k[1], k[0]))
    k2 = (kk**2).sum(axis=0)
    
    # set up wavenumber range
    if kiso is None:
        # no isotropic wavenumber grid specified
        kidx = np.argmin( np.array([l.max() for l in k]) )
        kiso = k[kidx][:N[kidx]/2]
    Niso = len(kiso)
    bins = np.digitize(k2.ravel(), kiso**2)
    
    # do fft
    #def iso_ps(q):
    f = np.fft.fftn(da.values, axes=axis_num)
    # sum isotropically
    fiso = np.bincount(bins,
                       weights=np.real(f*f.conj()).ravel(),
                       minlength=Niso)[:Niso]
    # replace zeros with nans
    fiso[fiso==0.] = np.nan
    # normalize properly
    #count = np.bincount(bins, minlength=Niso)[:Niso]
    #fiso *= (kiso / count)
    # (didn't work like I hoped)
    return xray.DataArray(fiso, coords={'k_iso': kiso})

def ts_iso_power_spec(sst):
    kiso = np.linspace(0,(5000.)**-1 / np.sqrt(2), 100)
    xvars = set(['x', 'y'])
    yvars = set(['x', 'y'])
    xvar = xvars.intersection(sst.dims).pop()
    yvar = yvars.intersection(sst.dims).pop()
    ssta = sst - sst.mean(dim=xvar)
    hwin = np.hanning(ds[yvar].shape[0])
    window = xray.DataArray(daskarray.from_array(hwin, hwin.shape), coords={yvar: ds[yvar]})
    sst_win = ssta * window
    return sst_win.groupby('time').apply( lambda q: xray_isotropic_power_spectrum(q, kiso=kiso, axis=(yvar,xvar)) )

# %%
dsT.sossheig.dims

# %%
t_ps = xray_isotropic_power_spectrum(dsT.sossheig[0,:,:])

# %%
Z_ps = xrft.isotropic_powerspectrum(dsT.sossheig[0,:,:],
                           window=True, detrend='constant')
# Z_ps.freq_x.plot()

# %%
dsT

# %%
def spectrum1(h, dt=1):
    """
    First cut at spectral estimation: very crude.
    
    Returns frequencies, power spectrum, and
    power spectral density.
    Only positive frequencies between (and not including)
    zero and the Nyquist are output.
    """
    nt = len(h)
    npositive = nt//2
    pslice = slice(1, npositive)
    freqs = np.fft.fftfreq(nt, d=dt)[pslice] 
    ft = np.fft.fft(h)[pslice]
    psraw = np.abs(ft) ** 2
    # Double to account for the energy in the negative frequencies.
    psraw *= 2
    # Normalization for Power Spectrum
    psraw /= nt**2
    # Convert PS to Power Spectral Density
    psdraw = psraw * dt * nt  # nt * dt is record length
    return freqs, psraw, psdraw


def spectrum2(h, dt=1, nsmooth=5):
    """
    Add simple boxcar smoothing to the raw periodogram.
    
    Chop off the ends to avoid end effects.
    """
    freqs, ps, psd = spectrum1(h, dt=dt)
    weights = np.ones(nsmooth, dtype=float) / nsmooth
    ps_s = np.convolve(ps, weights, mode='valid')
    psd_s = np.convolve(psd, weights, mode='valid')
    freqs_s = np.convolve(freqs, weights, mode='valid')
    return freqs_s, ps_s, psd_s
    



def spectrum3(h, dt=1, nsmooth=5):
    """
    Detrend first.
    """
    t = np.arange(len(h))
    p = np.polyfit(t, h, 1)
    h_detrended = h - np.polyval(p, t)
    return spectrum2(h_detrended, dt=dt, nsmooth=nsmooth)

# %%
def detrend(h):
    n = len(h)
    t = np.arange(n)
    p = np.polyfit(t, h, 1)
    h_detrended = h - np.polyval(p, t)
    return h_detrended
    
def quadwin(n):
    """
    Quadratic (or "Welch") window
    """
    t = np.arange(n)
    win = 1 - ((t - 0.5 * n) / (0.5 * n)) ** 2
    return win

def spectrum4(h, dt=1, nsmooth=5):
    """
    Detrend and apply a quadratic window.
    """
    n = len(h)

    h_detrended = detrend(h)
    
    winweights = quadwin(n)
    h_win = h_detrended * winweights
    
    freqs, ps, psd = spectrum2(h_win, dt=dt, nsmooth=nsmooth)
    
    # Compensate for the energy suppressed by the window.
    psd *= n / (winweights**2).sum()
    ps *= n**2 / winweights.sum()**2
    
    return freqs, ps, psd

# %%
T = dsT.sossheig[:,200,200]
T_ = dsT_.sossheig[:,200,200]

# %%
dt = 1/24
ns = 13
freqs1, ps1, psd1 = spectrum4(T.values, dt=dt, nsmooth=ns)
freqs2, ps2, psd2 = spectrum4(T_.values, dt=dt, nsmooth=ns)

# %%
fig = plt.figure(figsize=(10,6))
plt.loglog(freqs1, psd1, 'r')
plt.loglog(freqs2, psd2, 'k')
